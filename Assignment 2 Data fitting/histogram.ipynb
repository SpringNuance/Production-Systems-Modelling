# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Given data
data = {
    'Thickness': [5, 10, 15, 20, 5, 10, 15, 20, 5, 10, 15, 20, 5, 10, 15, 20, 5, 10, 15, 20,
                  5, 10, 15, 20, 5, 10, 15, 20, 5, 10, 15, 20, 5, 10, 15, 20, 5, 10, 15, 20],
    'Perimeter': [20, 36, 65, 117, 210, 378, 680, 65, 117, 210, 65, 117, 210, 20, 36, 65, 680, 65, 117, 210,
                  20, 36, 65, 117, 210, 378, 680, 65, 117, 210, 65, 117, 210, 20, 36, 65, 680, 65, 117, 210],
    'Weight': [0.09, 0.2, 0.6, 1.6, 3.9, 9.8, 24.4, 0.1, 0.3, 0.6, 0.2, 2.2, 9.2, 0.025, 0.2, 0.6, 12.0, 0.25, 0.6, 1.6,
               0.09, 0.2, 0.6, 1.6, 3.9, 9.8, 24.4, 0.1, 0.3, 0.6, 0.2, 2.2, 9.2, 0.025, 0.2, 0.6, 12.0, 0.25, 0.6, 1.6],
    'Cost': [5.6, 5.2, 5.4, 5.4, 4.1, 4.1, 4.2, 3.8, 2.7, 2.9, 4.1, 5.9, 5.4, 4.0, 5.6, 5.8, 2.9, 3.9, 4.0, 4.1,
             5.6, 5.2, 5.4, 5.4, 4.1, 4.1, 4.2, 3.8, 2.7, 2.9, 4.1, 5.9, 5.4, 4.0, 5.6, 5.8, 2.9, 3.9, 4.0, 4.1]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Initialize the Linear Regression model
model = LinearRegression(fit_intercept=True)

# Define the features and the target
X = df[['Thickness', 'Perimeter', 'Weight']]
y = df['Cost']

# Fit the model
model.fit(X, y)

# Get the coefficients and intercept
intercept = model.intercept_
coefficients = model.coef_

(intercept, coefficients)
# Out:
# (4.470465966508188, array([ 0.04709025, -0.00718671,  0.18913941]))

# %%
# fitting stadardied data

from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
scaler = StandardScaler()

# Standardize the features
X_std = scaler.fit_transform(X)

# Stan

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# Neural network residuals
nn_residuals = np.array([
    0.0003888595664, 1.5339716655182, 0.0819202244278, 0.1395158445133,
    0.0000027979770, 0.0008445516752, 0.0000322856604, 0.0232310993450,
    0.0003360062076, 0.0020552077438, 0.3553229501177, 0.0022764642730,
    0.0001978305756, 0.0014226886431, 0.0530294147430, 0.2043411710708,
    0.0000003535908, 0.0002299904946, 0.0432698604237, 0.0008867946699,
    0.0003888595664, 1.5339716655182, 0.0819202244278, 0.1395158445133,
    0.0000027979770, 0.0008445516752, 0.0000322856604, 0.0232310993450,
    0.0003360062076, 0.0020552077438, 0.3553229501177, 0.0022764642730,
    0.0001978305756, 0.0014226886431, 0.0530294147430, 0.2043411710708,
    0.0000003535908, 0.0002299904946, 0.0432698604237, 0.0008867946699
])

# Linear regression residuals
lr_residuals = np.array([
    -1.008439, -0.485089, -0.577789, -0.551155, -0.147822, -0.018716,
    0.731511, 1.140129, 1.212828, 0.681181, 0.695691, -0.936287,
    -0.510631, 0.810974, -0.587778, -0.730105, -0.826391, 0.584396,
    0.434241, 0.089252, -1.008439, -0.485089, -0.577789, -0.551155,
    -0.147822, -0.018716, 0.731511, 1.140129, 1.212828, 0.681181,
    0.695691, -0.936287, -0.510631, 0.810974, -0.587778, -0.730105,
    -0.826391, 0.584396, 0.434241, 0.089252
])

# Plot distributions
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.hist(nn_residuals, bins=20, color='skyblue', label='NN Residuals')
plt.title('Neural Network Residuals Distribution')
plt.xlabel('Residuals')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(lr_residuals, bins=20, color='lightgreen', label='LR Residuals')
plt.title('Linear Regression Residuals Distribution')
plt.xlabel('Residuals')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# Print max and min values
print(f"NN Residuals - Max: {nn_residuals.max()}, Min: {nn_residuals.min()}")
print(f"LR Residuals - Max: {lr_residuals.max()}, Min: {lr_residuals.min()}")
# Out:
# NN Residuals - Max: 1.5339716655182, Min: 3.535908e-07
# LR Residuals - Max: 1.212828, Min: -1.008439
